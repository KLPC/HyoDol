# %%
import numpy as np
import pandas as pd
import os
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39884/3744559544.py in <module>
#       2 import pandas as pd
#       3 import os
# ----> 4 import pandas_profiling
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\__init__.py in <module>
#       5
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       5
#       6
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\__init__.py in <module>
#       6 from pandas_profiling.config import Config, config
#       7 from pandas_profiling.controller import pandas_decorator
# ----> 8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#      10
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\profile_report.py in <module>
#       9
#      10 from pandas_profiling.config import config
# ---> 11 from pandas_profiling.model.describe import describe as describe_df
#      12 from pandas_profiling.model.messages import MessageType
#      13 from pandas_profiling.report import get_report_structure
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\model\describe.py in <module>
#      11 from pandas_profiling.model.correlations import calculate_correlation
#      12 from pandas_profiling.model.sample import Sample, get_sample
# ---> 13 from pandas_profiling.model.summary import (
#      14     get_duplicates,
#      15     get_messages,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas_profiling\model\summary.py in <module>
#      12 from pandas.core.arrays.integer import _IntegerDtype
#      13 from scipy.stats.stats import chisquare
# ---> 14 from visions.application.summaries.series import (
#      15     file_summary,
#      16     image_summary,
#
# ~\AppData\Roaming\Python\Python38\site-packages\visions\__init__.py in <module>
#       1 """Core functionality"""
# ----> 2 from visions import types, typesets, utils
#       3 from visions.dtypes.boolean import BoolDtype
#       4 from visions.functional import (
#       5     cast_to_detected,
#
# ~\AppData\Roaming\Python\Python38\site-packages\visions\typesets\__init__.py in <module>
# ----> 1 from visions.typesets.complete_set import CompleteSet
#       2 from visions.typesets.geometry_set import GeometrySet
#       3 from visions.typesets.standard_set import StandardSet
#       4 from visions.typesets.typeset import VisionsTypeset
#       5
#
# ~\AppData\Roaming\Python\Python38\site-packages\visions\typesets\complete_set.py in <module>
#      23     TimeDelta,
#      24 )
# ---> 25 from visions.typesets.typeset import VisionsTypeset
#      26
#      27
#
# ~\AppData\Roaming\Python\Python38\site-packages\visions\typesets\typeset.py in <module>
#       4 from typing import Any, Dict, Iterable, List, Optional, Set, Tuple, Type, TypeVar, Union
#       5
# ----> 6 import networkx as nx
#       7 import pandas as pd
#       8
#
# ModuleNotFoundError: No module named 'networkx'

# %%
os.listdir('./data')
# Out:
# ['log_doll_drug_consume.csv',
#  'log_doll_summary_YM.csv',
#  'log_doll_summary_YMD.csv',
#  'log_emergency_push.csv',
#  'scc_agency.csv',
#  'scc_doll.csv',
#  'scc_doll_option.csv',
#  'scc_ear_function_log.csv',
#  'scc_emergency_call.csv',
#  'scc_user.csv',
#  'scc_user_doll_group.csv',
#  'survey_preprocessed.csv']

# %%
data_path = 'C:\\Users\\LSH\\Desktop\\효돌\\data_csv\\data\\'

agency = pd.read_csv(data_path+'scc_agency.csv')
doll = pd.read_csv(data_path+'scc_doll.csv', sep = ',')
doll_option = pd.read_csv(data_path+'scc_doll_option.csv',sep = ',')
user = pd.read_csv(data_path+'scc_user.csv',sep = ';')
user_doll_group = pd.read_csv(data_path+'scc_user_doll_group.csv',sep = ';')

ear_function_log = pd.read_csv(data_path+'scc_ear_function_log.csv',sep = ';')
emergency_call = pd.read_csv(data_path+'scc_emergency_call.csv',sep = ';')

log_doll_drug_consume = pd.read_csv(data_path+'log_doll_drug_consume.csv',sep = ';')
log_doll_summary_YM = pd.read_csv(data_path+'log_doll_summary_YM.csv',sep = ';')
log_doll_summary_YMD = pd.read_csv(data_path+'log_doll_summary_YMD.csv',sep = ';')
log_emergency_push = pd.read_csv(data_path+'log_emergency_push.csv',sep = ';')

# %% [markdown]
# ## 목표: user  -  user_doll_group  -  agency  -  doll 전처리 / 통합

# %%
print(user.columns)    # 앱 사용자: 관리사계정
print(user_doll_group.columns)
print(agency.columns)  # 
print(doll.columns)
# Out:
# Index(['user_id', 'is_resign', 'agency_code', 'alarm_emergency',
#        'alarm_emergency_call', 'alarm_low_battery', 'alarm_disconnect'],
#       dtype='object')
# Index(['group_id', 'agency_code', 'doll_id', 'user_group_member_id', 'is_host',
#        'is_agency'],
#       dtype='object')
# Index(['agency_id', 'agency_name'], dtype='object')
# Index(['doll_id', 'user_id', 'battery', 'active_monitor', 'sex',
#        'HOUR(wakeup)', 'HOUR(breakfast)', 'HOUR(lunch)', 'HOUR(dinner)',
#        'HOUR(sleep)', 'ventilation_walk', 'is_edited', 'drug1', 'drug2',
#        'drug3', 'drug4', 'drug5', 'drug6', 'drug7', 'regsted_year',
#        'regsted_month', 'mac_id', 'disease1', 'disease2', 'disease3',
#        'serial_number', 'age'],
#       dtype='object')

# %%
print( doll.nunique(), '\n')
print( user.nunique(), '\n')
print( user_doll_group.nunique(), '\n')
# Out:
# doll_id             5055
# user_id              900
# battery               72
# active_monitor        41
# sex                    3
# HOUR(wakeup)          20
# HOUR(breakfast)       21
# HOUR(lunch)           20
# HOUR(dinner)          24
# HOUR(sleep)           24
# ventilation_walk       4
# is_edited              2
# drug1                  2
# drug2                  2
# drug3                  2
# drug4                  2
# drug5                  2
# drug6                  2
# drug7                  2
# regsted_year           4
# regsted_month         12
# mac_id              2950
# disease1               2
# disease2               2
# disease3               2
# serial_number       2746
# age                   77
# dtype: int64
#
# user_id                 2132
# is_resign                  2
# agency_code              150
# alarm_emergency            2
# alarm_emergency_call       2
# alarm_low_battery          2
# alarm_disconnect           1
# dtype: int64
#
# group_id                9878
# agency_code              124
# doll_id                 8067
# user_group_member_id    1484
# is_host                    2
# is_agency                  2
# dtype: int64

# %% [markdown]
# ### 전처리 순서:
# 1. user_doll_group 에 대해 user의 doll_id 키값으로 user_id 추가
# 2. user_doll_group 과 user 의 agency 매칭시키기
# 3. doll 에 나머지 통합 (user, user_group, agnecy)

# %%
# row 2088 ; userID 2088 개
user = user[~user['agency_code'].isnull().values]
user['agency_code'] = user['agency_code'].apply(int)

# 설문 45: scc_agency 에 없는 user 삭제
user = user[ user['agency_code'].apply(lambda x: x not in [3,4,1111, 7, 8, 9, 324, 104211001000, 
                                                             991234123001, 999999901001])]

agency_name_dict = dict(zip(agency['agency_id'], agency['agency_name']))
user['agency_name'] = user['agency_code'].apply(lambda x: agency_name_dict[x] )

# %%
# doll 에 없는 애들 제거 
# user_group 에 user id 추가
doll_user_dict = dict(zip( doll['doll_id'],doll['user_id']))
user_doll_group = user_doll_group[~user_doll_group['doll_id'].apply(lambda x: x not in doll_user_dict.keys() )]
user = user[~user['user_id'].apply(lambda x: x not in set(doll_user_dict.values()) )]
user_doll_group['user_id'] = user_doll_group['doll_id'].apply(lambda x: doll_user_dict[x])

# %% [markdown]
# ### 1. user_id 기준으로 user & user_doll_group  merge 시키기

# %%
user_doll_group
# Out:
#       group_id   agency_code  doll_id  user_group_member_id  is_host  \
# 938       1262           NaN   123533                   100        1
# 939       1263           NaN   123534                   101        1
# 940       1264           NaN   123535                   101        1
# 941       1265           NaN   123536                   102        1
# 942       1266           NaN   123537                   102        1
# ...        ...           ...      ...                   ...      ...
# 9872     15334  2.042110e+11   135025                  7982        1
# 9874     15336  1.000000e+00   135027                  9216        1
# 9875     15337  1.000000e+00   135028                  9216        1
# 9876     15338  1.000000e+00   135029                  9217        1
# 9877     15339  1.000000e+00   135030                  9217        1
#
#       is_agency  user_id
# 938           1      100
# 939           1      101
# 940           1      101
# 941           1      102
# 942           1      102
# ...         ...      ...
# 9872          1     7982
# 9874          0     9181
# 9875          0     9181
# 9876          0     9181
# 9877          0     9171
#
# [4792 rows x 7 columns]

# %%
user_doll_group
# Out:
#       group_id   agency_code  doll_id  user_group_member_id  is_host  \
# 938       1262           NaN   123533                   100        1
# 939       1263           NaN   123534                   101        1
# 940       1264           NaN   123535                   101        1
# 941       1265           NaN   123536                   102        1
# 942       1266           NaN   123537                   102        1
# ...        ...           ...      ...                   ...      ...
# 9872     15334  2.042110e+11   135025                  7982        1
# 9874     15336  1.000000e+00   135027                  9216        1
# 9875     15337  1.000000e+00   135028                  9216        1
# 9876     15338  1.000000e+00   135029                  9217        1
# 9877     15339  1.000000e+00   135030                  9217        1
#
#       is_agency  user_id
# 938           1      100
# 939           1      101
# 940           1      101
# 941           1      102
# 942           1      102
# ...         ...      ...
# 9872          1     7982
# 9874          0     9181
# 9875          0     9181
# 9876          0     9181
# 9877          0     9171
#
# [4792 rows x 7 columns]

# %%
user_doll_group.rename(columns= {'agency_code': 'gp_agency_code'}, inplace = True)
merged_ = pd.merge(user, user_doll_group, on = 'user_id')
merged_['gp_agency_name']= merged_.loc[:, 'gp_agency_code'].apply(lambda x: agency_name_dict[x] if x in agency_name_dict.keys() else None )

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(merged_, figsize = (10,5))

# %%
non_null = merged_ [ ~merged_.isnull().any(axis=1)]
non_null['gp_agency_code'] = non_null['gp_agency_code'].apply(int)
non_null[ non_null['gp_agency_code'] == non_null['agency_code']  ]

print( non_null[ non_null['agency_code'] == non_null['gp_agency_code']  ].nunique(), '\n')
print(non_null[ non_null['agency_code'] != non_null['gp_agency_code']  ].nunique(), '\n')
# Out:
# user_id                  715
# is_resign                  2
# agency_code              116
# alarm_emergency            2
# alarm_emergency_call       2
# alarm_low_battery          2
# alarm_disconnect           1
# agency_name              116
# group_id                4011
# gp_agency_code           116
# doll_id                 2909
# user_group_member_id    1160
# is_host                    1
# is_agency                  2
# gp_agency_name           116
# dtype: int64
#
# user_id                 112
# is_resign                 2
# agency_code              43
# alarm_emergency           2
# alarm_emergency_call      2
# alarm_low_battery         2
# alarm_disconnect          1
# agency_name              43
# group_id                441
# gp_agency_code           21
# doll_id                 304
# user_group_member_id    210
# is_host                   1
# is_agency                 2
# gp_agency_name           21
# dtype: int64
# C:\Users\LSH\AppData\Local\Temp/ipykernel_39884/2026510017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_null['gp_agency_code'] = non_null['gp_agency_code'].apply(int)

# %%
# 원래뭐였는지 보고 관련성이 있나 확인
set(merged_[merged_['gp_agency_code'].isnull().values]['agency_name'])
# Out:
# {'개인 사용자',
#  '광교종합사회복지관',
#  '광양시 재가',
#  '남부노인복지관',
#  '별빛마을',
#  '아산시노인종합복지관',
#  '전체',
#  '춘천시장애인종합복지관',
#  '춘천시청',
#  '태백노인복지센터',
#  '포스코 광양'}

# %%
# https://docs.google.com/spreadsheets/d/1z5FgYLsbAmRsQvQuTzCKR_AmJZySmgCuHAL9RKO8Aj0/edit#gid=520402378
gp_null = merged_[merged_['gp_agency_code'].isnull().values]

# %%
# 태백노인복지센터 NA 값 2개
tb_1 = merged_[ merged_['agency_name']== '포스코 광양' ]
tb_1[ tb_1.isnull().any(axis = 1) ]
merged_[ merged_['user_group_member_id'] == 7609 ]
# Out:
#       user_id  is_resign   agency_code  alarm_emergency  alarm_emergency_call  \
# 1454     7609          0  714623007001                0                     1
# 1455     7609          0  714623007001                0                     1
# 1456     7609          0  714623007001                0                     1
# 1457     7609          0  714623007001                0                     1
# 1458     7609          0  714623007001                0                     1
# 1459     7609          0  714623007001                0                     1
# 1460     7609          0  714623007001                0                     1
# 1461     7609          0  714623007001                0                     1
# 1462     7609          0  714623007001                0                     1
# 1463     7609          0  714623007001                0                     1
# 1464     7609          0  714623007001                0                     1
# 1465     7609          0  714623007001                0                     1
# 1466     7609          0  714623007001                0                     1
# 1467     7609          0  714623007001                0                     1
# 1468     7609          0  714623007001                0                     1
# 1469     7609          0  714623007001                0                     1
# 1470     7609          0  714623007001                0                     1
# 1471     7609          0  714623007001                0                     1
# 1472     7609          0  714623007001                0                     1
# 1473     7609          0  714623007001                0                     1
# 1474     7609          0  714623007001                0                     1
# 1475     7609          0  714623007001                0                     1
# 1476     7609          0  714623007001                0                     1
# 1477     7609          0  714623007001                0                     1
# 1478     7609          0  714623007001                0                     1
# 1479     7609          0  714623007001                0                     1
# 1480     7609          0  714623007001                0                     1
# 1481     7609          0  714623007001                0                     1
# 1482     7609          0  714623007001                0                     1
# 1483     7609          0  714623007001                0                     1
# 1484     7609          0  714623007001                0                     1
# 1485     7609          0  714623007001                0                     1
# 1486     7609          0  714623007001                0                     1
# 1496     7609          0  714623007001                0                     1
# 1497     7609          0  714623007001                0                     1
# 3744       태백노인복지센터
# 3745       태백노인복지센터
# 3746       태백노인복지센터

# %%
# 춘천시청 NA 값 10
tb_1 = merged_[ merged_['agency_name']== '춘천시장애인종합복지관' ]
tb_1[ tb_1.isnull().any(axis = 1) ]
merged_[ merged_['user_group_member_id'] == 7512 ] # 7353, 7337,16
# Out:
#      user_id  is_resign  agency_code  alarm_emergency  alarm_emergency_call  \
# 61      7195          0  14211001001                1                     1
# 62      7195          0  14211001001                1                     1
# 63      7195          0  14211001001                1                     1
# 64      7195          0  14211001001                1                     1
# 65      7195          0  14211001001                1                     1
# 66      7195          0  14211001001                1                     1
# 133     7202          0  14211001004                1                     1
# 134     7202          0  14211001004                1                     1
# 135     7202          0  14211001004                1                     1
# 136     7202          0  14211001004                1                     1
# 137     7202          0  14211001004                1                     1
# 138     7202          0  14211001004                1                     1
# 139     7202          0  14211001004                1                     1
# 140     7202          0  14211001004                1                     1
# 141     7202          0  14211001004                1                     1
# 142     7202          0  14211001004                1                     1
# 143     7202          0  14211001004                1                     1
# 144     7202          0  14211001004                1                     1
# 145     7202          0  14211001004                1                     1
# 146     7202          0  14211001004                1                     1
# 147     7202          0  14211001004                1                     1
# 148     7202          0  14211001004                1                     1
# 149     7202          0  14211001004                1                     1
# 150     7202          0  14211001004                1                     1
# 151     7202          0  14211001004                1                     1
# 152     7202          0  14211001004                1                     1
#
#      alarm_low_battery  alarm_disconnect  agency_name  group_id  \
# 61                   1                 0  춘천시장애인종합복지관      4137
# 62                   1                 0  춘천시장애인종합복지관      4146
# 63                   1                 0  춘천시장애인종합복지관      4152
# 64                   1                 0  춘천시장애인종합복지관      4174
# 65                   1                 0  춘천시장애인종합복지관      4175
# 66                   1                 0  춘천시장애인종합복지관      4188
# 133                  0                 0         별빛마을      4136
# 134                  0                 0         별빛마을      4138
# 135                  0                 0         별빛마을      4150
# 136                  0                 0         별빛마을      4151
# 137                  0                 0         별빛마을      4154
# 138                  0                 0         별빛마을      4157
# 139                  0                 0         별빛마을      4159
# 140                  0                 0         별빛마을      4160
# 141                  0                 0         별빛마을      4162
# 142                  0                 0         별빛마을      4163
# 143                  0                 0         별빛마을      4164
# 144                  0                 0         별빛마을      4168
# 145                  0                 0         별빛마을      4170
# 146                  0                 0         별빛마을      4172
# 147                  0                 0         별빛마을      4180
# 148                  0                 0         별빛마을      4182
# 149                  0                 0         별빛마을      4183
# 150                  0                 0         별빛마을      4191
# 151                  0                 0         별빛마을      4192
# 152                  0                 0         별빛마을      4205
#
#      gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 61     1.421100e+10   124258                  7512        1          1
# 62              NaN   123945                  7512        1          1
# 63              NaN   123811                  7512        1          1
# 64              NaN   123792                  7512        1          1
# 65     0.000000e+00   123803                  7512        1          1
# 66              NaN   123813                  7512        1          1
# 133             NaN   125426                  7512        1          1
# 134             NaN   125450                  7512        1          1
# 135             NaN   125561                  7512        1          1
# 136    1.421100e+10   125585                  7512        1          1
# 137             NaN   123948                  7512        1          1
# 138             NaN   125582                  7512        1          1
# 139             NaN   125579                  7512        1          1
# 140             NaN   125581                  7512        1          1
# 141             NaN   124080                  7512        1          1
# 142             NaN   125583                  7512        1          1
# 143             NaN   125440                  7512        1          1
# 144             NaN   125584                  7512        1          1
# 145             NaN   125593                  7512        1          1
# 146             NaN   125591                  7512        1          1
# 147             NaN   124076                  7512        1          1
# 148             NaN   123926                  7512        1          1
# 149             NaN   123923                  7512        1          1
# 150             NaN   125576                  7512        1          1
# 151             NaN   125588                  7512        1          1
# 152    1.421100e+10   125624                  7512        1          1
#
#     gp_agency_name
# 61            춘천시청
# 62            None
# 63            None
# 64            None
# 65              전체
# 66            None
# 133           None
# 134           None
# 135           None
# 136           춘천시청
# 137           None
# 138           None
# 139           None
# 140           None
# 141           None
# 142           None
# 143           None
# 144           None
# 145           None
# 146           None
# 147           None
# 148           None
# 149           None
# 150           None
# 151           None
# 152           춘천시청

# %%
# 춘천시청 NA 값 5개
tb_1 = merged_[ merged_['agency_name']== '춘천시개인' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
#merged_[ merged_['user_group_member_id'] == 7353 ] # 7353, 7512, 16
# Out:
# Empty DataFrame
# Columns: [user_id, is_resign, agency_code, alarm_emergency, alarm_emergency_call, alarm_low_battery, alarm_disconnect, agency_name, group_id, gp_agency_code, doll_id, user_group_member_id, is_host, is_agency, gp_agency_name]
# Index: []

# %%
# 전체 NA 값 1565 개
tb_1 = merged_[ merged_['agency_name']== '전체' ]
tb_1[ tb_1.isnull().any(axis = 1) ]
#set(tb_1[ tb_1.isnull().any(axis = 1) ]['user_group_member_id'])
#merged_[ merged_['user_group_member_id'] == 7353 ]
# Out:
#      user_id  is_resign  agency_code  alarm_emergency  alarm_emergency_call  \
# 0       7187          0            0                0                     1
# 1       7187          0            0                0                     1
# 7        100          0            0                0                     1
# 8        100          0            0                0                     1
# 9        100          0            0                0                     1
# ..       ...        ...          ...              ...                   ...
# 448     7369          0            0                1                     1
# 463     7372          0            0                1                     1
# 466     7373          0            0                1                     1
# 467     7373          0            0                1                     1
# 470     7374          0            0                1                     1
#
#      alarm_low_battery  alarm_disconnect agency_name  group_id  \
# 0                    0                 0          전체      1346
# 1                    0                 0          전체      1347
# 7                    0                 0          전체      1262
# 8                    0                 0          전체      1673
# 9                    0                 0          전체      1675
# ..                 ...               ...         ...       ...
# 448                  1                 0          전체      3001
# 463                  1                 0          전체      2950
# 466                  1                 0          전체      2991
# 467                  1                 0          전체      2992
# 470                  1                 0          전체      3294
#
#      gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 0               NaN   123581                  7187        1          1
# 1               NaN   123582                  7187        1          1
# 7               NaN   123533                   100        1          1
# 8               NaN   123900                   100        1          1
# 9               NaN   123902                   100        1          1
# ..              ...      ...                   ...      ...        ...
# 448             NaN   125027                  7369        1          1
# 463             NaN   124984                  7372        1          1
# 466             NaN   125020                  7373        1          1
# 467             NaN   125021                  7373        1          1
# 470             NaN   125272                  7374        1          1
#
#     gp_agency_name
# 0             None
# 1             None
# 7             None
# 8             None
# 9             None
# ..             ...
# 448           None
# 463           None
# 466           None
# 467           None
# 470           None
#
# [189 rows x 15 columns]

# %%
# 아산시노인종합복지관 NA 값 21개
tb_1 = merged_[ merged_['agency_name']== '별빛마을']
len(tb_1[ tb_1.isnull().any(axis = 1) ] )
set(tb_1[ tb_1.isnull().any(axis = 1) ]['user_group_member_id'])
merged_[ merged_['user_group_member_id'] == 7433 ] # 16, 7512
# Out:
#      user_id  is_resign  agency_code  alarm_emergency  alarm_emergency_call  \
# 101     7202          0  14211001004                1                     1
# 157     7202          0  14211001004                1                     1
#
#      alarm_low_battery  alarm_disconnect agency_name  group_id  \
# 101                  0                 0        별빛마을      3505
# 157                  0                 0        별빛마을      5550
#
#      gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 101             NaN   125450                  7433        1          1
# 157             NaN   126477                  7433        1          1
#
#     gp_agency_name
# 101           None
# 157           None

# %%
# 남부노인복지관 NA 값 5개
tb_1 = merged_[ merged_['agency_name']== '남부노인복지관' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
len(tb_1[ tb_1.isnull().any(axis = 1) ] )
merged_[ merged_['user_group_member_id'] == 7429 ] # 7353, 7512, 16
# Out:
#       user_id  is_resign   agency_code  alarm_emergency  alarm_emergency_call  \
# 3        8122          0   34420001001                1                     1
# 514      7429          0             1                1                     1
# 515      7429          0             1                1                     1
# 516      7429          0             1                1                     1
# 518      7429          0             1                1                     1
# 519      7429          0             1                1                     1
# 520      7429          0             1                1                     1
# 521      7429          0             1                1                     1
# 522      7429          0             1                1                     1
# 523      7429          0             1                1                     1
# 524      7429          0             1                1                     1
# 525      7429          0             1                1                     1
# 528      7429          0             1                1                     1
# 529      7429          0             1                1                     1
# 530      7429          0             1                1                     1
# 764      7531          0   14211001005                1                     1
# 795      7531          0   14211001005                1                     1
# 1412     7600          0   31153002002                1                     0
# 2067     7945          0             1                1                     1
# 2547     8093          0   34420001001                1                     1
# 2554     8091          0   34420001001                1                     1
# 2560     8092          0   34420001001                1                     1
# 2571     8094          0   34420001001                1                     1
# 2583     8095          0   34420001001                1                     1
# 2590     8096          0   34420001001                1                     1
# 2598     8097          0   34420001001                1                     1
# 2612     8099          0   34420001001                1                     1
# 2627     8101          0   34420001001                1                     1
# 2636     8102          0   34420001001                1                     1
# 2643     8103          0   34420001001                1                     1
# 2650     8105          0   34420001001                1                     1
# 2659     8106          0   34420001001                1                     1
# 2673     8108          0   34420001001                1                     1
# 2682     8110          0   34420001001                1                     1
# 2691     8111          0   34420001001                1                     1
# 2695     8112          0   34420001001                1                     1
# 2702     8113          0   34420001001                1                     1
# 2716     8115          0   34420001001                1                     1
# 2726     8116          0   34420001001                1                     1
# 2731     8117          0   34420001001                1                     1
# 2741     8118          0   34420001001                1                     1
# 2746     8119          0   34420001001                1                     1
# 2755     8121          0   34420001001                1                     1
# 2763     8123          0             1                1                     1
# 2779     8125          0   34420001001                1                     1
# 2788     8126          0   34420001001                1                     1
# 2798     8127          0   34420001001                1                     1
# 2813     8129          0   34420001001                1                     1
# 2904     8171          1             1                1                     1
# 2985     8607          0             1                1                     1
# 3459     8536          0  471144004012                0                     0
# 3856     8714          0  724213007001                1                     1
# 3914     8846          0             1                1                     1
#
#       alarm_low_battery  alarm_disconnect  agency_name  group_id  \
# 3                     1                 0   아산시노인종합복지관      9326
# 514                   1                 0       개인 사용자      3472
# 515                   1                 0       개인 사용자      5054
# 516                   1                 0       개인 사용자      5365
# 518                   1                 0       개인 사용자      5714
# 519                   1                 0       개인 사용자      7054
# 520                   1                 0       개인 사용자      7162
# 521                   1                 0       개인 사용자      7210
# 522                   1                 0       개인 사용자      7305
# 523                   1                 0       개인 사용자      7306
# 524                   1                 0       개인 사용자      8597
# 525                   1                 0       개인 사용자     11880
# 528                   1                 0       개인 사용자     12615
# 529                   1                 0       개인 사용자     13287
# 530                   1                 0       개인 사용자     14400
# 764                   0                 0      남부노인복지관      5298
# 795                   0                 0      남부노인복지관     13322
# 1412                  0                 0  구로어르신돌봄통합센터     11625
# 2067                  1                 0       개인 사용자      7053
# 2547                  0                 0   아산시노인종합복지관      9328
# 2554                  0                 0   아산시노인종합복지관      9327
# 2560                  0                 0   아산시노인종합복지관      9308
# 2571                  1                 0   아산시노인종합복지관      9303
# 2583                  1                 0   아산시노인종합복지관      9321
# 2590                  0                 0   아산시노인종합복지관      9317
# 2598                  1                 0   아산시노인종합복지관      9302
# 2612                  1                 0   아산시노인종합복지관      9306
# 2627                  1                 0   아산시노인종합복지관      9304
# 2636                  1                 0   아산시노인종합복지관      9331
# 2643                  0                 0   아산시노인종합복지관      9314
# 2650                  0                 0   아산시노인종합복지관      9319
# 2659                  1                 0   아산시노인종합복지관      9323
# 2673                  1                 0   아산시노인종합복지관      9309
# 2682                  0                 0   아산시노인종합복지관      9325
# 2691                  0                 0   아산시노인종합복지관      9330
# 2695                  1                 0   아산시노인종합복지관      9318
# 2702                  1                 0   아산시노인종합복지관      9324
# 2716                  1                 0   아산시노인종합복지관      9322
# 2726                  1                 0   아산시노인종합복지관      9313
# 2731                  0                 0   아산시노인종합복지관      9307
# 2741                  1                 0   아산시노인종합복지관      9320
# 2746                  0                 0   아산시노인종합복지관      9312
# 2755                  1                 0   아산시노인종합복지관      9305
# 2763                  1                 0       개인 사용자      9316
# 2779                  0                 0   아산시노인종합복지관      9311
# 2788                  1                 0   아산시노인종합복지관      9310
# 2798                  0                 0   아산시노인종합복지관      9315
# 2813                  0                 0   아산시노인종합복지관      9329
# 2904                  1                 0       개인 사용자     11624
# 2985                  1                 0       개인 사용자     11957
# 3459                  0                 0    용산노인종합복지관     11793
# 3856                  0                 0  적십자사 대구광역지사     13675
# 3914                  1                 0       개인 사용자     13616
#
#       gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 3       3.442000e+10   129639                  7429        1          1
# 514              NaN   125418                  7429        1          1
# 515              NaN   126449                  7429        1          1
# 516              NaN   126718                  7429        1          1
# 518              NaN   127029                  7429        1          1
# 519     1.000000e+00   128143                  7429        1          0
# 520     1.000000e+00   128240                  7429        1          0
# 521     1.000000e+00   128283                  7429        1          0
# 522     1.000000e+00   128359                  7429        1          0
# 2726     아산시노인종합복지관
# 2731     아산시노인종합복지관
# 2741     아산시노인종합복지관
# 2746     아산시노인종합복지관
# 2755     아산시노인종합복지관
# 2763         개인 사용자
# 2779     아산시노인종합복지관
# 2788     아산시노인종합복지관
# 2798     아산시노인종합복지관
# 2813         개인 사용자
# 2904       금천구노인복지관
# 2985         개인 사용자
# 3459      용산노인종합복지관
# 3856         개인 사용자
# 3914         개인 사용자

# %%
# 광양시청 NA 값 122개
tb_1 = merged_[ merged_['agency_name']== '광양시청' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
set(tb_1[ tb_1.isnull().any(axis = 1) ]['user_group_member_id'])
# Out:
# set()

# %%
# 광양시 재가 NA 값 4개
tb_1 = merged_[ merged_['agency_name']== '광양시 재가' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
merged_[ merged_['user_group_member_id'] == 96 ] # 7385, 96, 7389
# Out:
#       user_id  is_resign   agency_code  alarm_emergency  alarm_emergency_call  \
# 487      7385          0   24623001901                1                     1
# 2274     8012          0  212911003001                1                     1
# 2275     8012          0  212911003001                1                     1
# 2276     8012          0  212911003001                1                     1
# 2303     8014          0             1                1                     1
# 2305     8015          0             1                1                     1
#
#       alarm_low_battery  alarm_disconnect agency_name  group_id  \
# 487                   1                 0      광양시 재가      3047
# 2274                  1                 0     광주동구보건소      8608
# 2275                  1                 0     광주동구보건소      8610
# 2276                  1                 0     광주동구보건소      8612
# 2303                  1                 0      개인 사용자      8609
# 2305                  1                 0      개인 사용자      8611
#
#       gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 487              NaN   125052                    96        1          1
# 2274    2.462300e+10   128527                    96        1          1
# 2275    2.462300e+10   128521                    96        1          1
# 2276    2.462300e+10   128878                    96        1          1
# 2303    2.462300e+10   128412                    96        1          1
# 2305    2.462300e+10   128411                    96        1          1
#
#      gp_agency_name
# 487            None
# 2274           광양시청
# 2275           광양시청
# 2276           광양시청
# 2303           광양시청
# 2305           광양시청

# %%
# 광양시 재가 NA 값 2개
tb_1 = merged_[ merged_['agency_name']== '광교종합사회복지관' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
#merged_[ merged_['user_group_member_id'] == 7242 ]
# Out:
#      user_id  is_resign   agency_code  alarm_emergency  alarm_emergency_call  \
# 226     7242          0  434111704002                1                     1
# 227     7242          0  434111704002                1                     1
#
#      alarm_low_battery  alarm_disconnect agency_name  group_id  \
# 226                  0                 0   광교종합사회복지관      1915
# 227                  0                 0   광교종합사회복지관      1916
#
#      gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 226             NaN   124118                  7242        1          1
# 227             NaN   124119                  7242        1          1
#
#     gp_agency_name
# 226           None
# 227           None

# %%
# 광양시 재가 NA 값 2개
tb_1 = merged_[ merged_['agency_name']== '개인 사용자' ]
tb_1[ tb_1.isnull().any(axis = 1) ] 
#set(tb_1[ tb_1.isnull().any(axis = 1) ]['user_group_member_id'])
#merged_[ merged_['user_group_member_id'] == 7242 ]
# Out:
#       user_id  is_resign  agency_code  alarm_emergency  alarm_emergency_call  \
# 279      7337          0            1                0                     1
# 280      7337          0            1                0                     1
# 285      7337          0            1                0                     1
# 286      7337          0            1                0                     1
# 287      7337          0            1                0                     1
# ...       ...        ...          ...              ...                   ...
# 577      7502          1            1                1                     1
# 578      7503          1            1                1                     1
# 579      7504          0            1                1                     1
# 979      7580          0            1                1                     1
# 3908     8846          0            1                1                     1
#
#       alarm_low_battery  alarm_disconnect agency_name  group_id  \
# 279                   0                 0      개인 사용자      2130
# 280                   0                 0      개인 사용자      2171
# 285                   0                 0      개인 사용자      2187
# 286                   0                 0      개인 사용자      2193
# 287                   0                 0      개인 사용자      2828
# ...                 ...               ...         ...       ...
# 577                   1                 0      개인 사용자      3824
# 578                   1                 0      개인 사용자      3825
# 579                   1                 0      개인 사용자      3826
# 979                   1                 0      개인 사용자      5618
# 3908                  1                 0      개인 사용자     13164
#
#       gp_agency_code  doll_id  user_group_member_id  is_host  is_agency  \
# 279              NaN   124224                  7337        1          1
# 280              NaN   124264                  7337        1          1
# 285              NaN   124280                  7337        1          1
# 286              NaN   124286                  7337        1          1
# 287              NaN   124911                  7337        1          1
# ...              ...      ...                   ...      ...        ...
# 577              NaN   125594                  7502        1          1
# 578              NaN   125595                  7503        1          1
# 579              NaN   125596                  7504        1          1
# 979              NaN   126434                  7650        1          1
# 3908             NaN   133215                  8152        1          1
#
#      gp_agency_name
# 279            None
# 280            None
# 285            None
# 286            None
# 287            None
# ...             ...
# 577            None
# 578            None
# 579            None
# 979            None
# 3908           None
#
# [82 rows x 15 columns]

# %% [markdown]
# ### 2. user_group NA 날리고 불일치는 user_group 기준으로 변경, match_agc 추가

# %%
non_null['match_agc'] = 1 * (non_null['agency_code'] == non_null['gp_agency_code']  )
non_null.drop(columns = ['agency_code', 'agency_name'], inplace = True)
non_null.rename(columns = {'gp_agency_code': 'agency_code', 'gp_agency_name':'agency_name'}, inplace = True)
# Out:
# C:\Users\LSH\AppData\Local\Temp/ipykernel_39884/192781681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_null['match_agc'] = 1 * (non_null['agency_code'] == non_null['gp_agency_code']  )
# C:\Users\LSH\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\LSH\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
non_null
# Out:
#       user_id  is_resign  alarm_emergency  alarm_emergency_call  \
# 2        8122          0                1                     1
# 3        8122          0                1                     1
# 4        8122          0                1                     1
# 5        8122          0                1                     1
# 6        8122          0                1                     1
# ...       ...        ...              ...                   ...
# 4762     9181          0                1                     1
# 4763     9181          0                1                     1
# 4764     9181          0                1                     1
# 4765     9215          0                1                     1
# 4766     9202          1                1                     1
#
#       alarm_low_battery  alarm_disconnect  group_id  agency_code  doll_id  \
# 2                     1                 0      8692  34420001001   129639
# 3                     1                 0      9326  34420001001   129639
# 4                     1                 0     10028  34420001001   129639
# 5                     1                 0     15202  34420001001   134932
# 6                     1                 0     15212  34420001001   134932
# ...                 ...               ...       ...          ...      ...
# 4762                  1                 0     15336            1   135027
# 4763                  1                 0     15337            1   135028
# 4764                  1                 0     15338            1   135029
# 4765                  1                 0     15326            1   135023
# 4766                  1                 0     15322            1   135021
#
#       user_group_member_id  is_host  is_agency agency_name  match_agc
# 2                     8090        1          1  아산시노인종합복지관          1
# 3                     7429        1          1  아산시노인종합복지관          1
# 4                     8090        1          1  아산시노인종합복지관          1
# 5                     8122        1          1  아산시노인종합복지관          1
# 6                     8090        1          1  아산시노인종합복지관          1
# ...                    ...      ...        ...         ...        ...
# 4762                  9216        1          0      개인 사용자          1
# 4763                  9216        1          0      개인 사용자          1
# 4764                  9217        1          0      개인 사용자          1
# 4765                  9215        1          0      개인 사용자          1
# 4766                  9202        1          0      개인 사용자          1
#
# [4452 rows x 14 columns]

# %% [markdown]
# ## 3. doll 과 나머지 통합

# %%
doll_option.drop(columns = 'is_edited', inplace = True)
doll_merged = pd.merge( doll, non_null, on = ['user_id', 'doll_id'])
doll_merged = pd.merge( doll_merged, doll_option, on = 'doll_id' )

# %%
doll_merged.to_csv('doll_merged.csv', index = False)

# %%
doll_merged.nunique()
# Out:
# doll_id                 3207
# user_id                  760
# battery                   72
# active_monitor            35
# sex                        3
# HOUR(wakeup)              20
# HOUR(breakfast)           20
# HOUR(lunch)               19
# HOUR(dinner)              23
# HOUR(sleep)               23
# ventilation_walk           4
# is_edited                  2
# drug1                      2
# drug2                      2
# drug3                      2
# drug4                      2
# drug5                      2
# drug6                      2
# drug7                      2
# regsted_year               4
# regsted_month             12
# mac_id                  2573
# disease1                   2
# disease2                   2
# disease3                   2
# serial_number_x         2000
# age                       68
# is_resign                  2
# alarm_emergency            2
# alarm_emergency_call       2
# alarm_low_battery          2
# alarm_disconnect           1
# group_id                4452
# agency_code              119
# user_group_member_id    1261
# is_host                    1
# is_agency                  2
# agency_name              119
# match_agc                  2
# no_alarm                   2
# relig1                    25
# relig2                    25
# relig3                    24
# relig4                    21
# relig5                    17
# religion_alarm             2
# calender_type              2
# is_active_detect           1
# grandFM                    2
# honorFM                    2
# right_ear_function       223
# left_ear_function        213
# serial_number_y         2000
# dtype: int64

# %%
indi_user.loc[:, ['user_group_member_id', 'user_id']]#.value_counts()
# Out:
#       user_group_member_id  user_id
# 42                    7232     7232
# 46                    7337     7337
# 47                    7337     7337
# 48                    7337     7337
# 49                    7337     7337
# ...                    ...      ...
# 4446                  9215     9215
# 4448                  9216     9181
# 4449                  9216     9181
# 4450                  9217     9181
# 4451                  9217     9171
#
# [989 rows x 2 columns]

# %%
#indi_user[['user_group_member_id', 'user_id']].value_counts()
indi_user[['user_group_member_id', 'user_id']]
# Out:
#       user_group_member_id  user_id
# 42                    7232     7232
# 46                    7337     7337
# 47                    7337     7337
# 48                    7337     7337
# 49                    7337     7337
# ...                    ...      ...
# 4446                  9215     9215
# 4448                  9216     9181
# 4449                  9216     9181
# 4450                  9217     9181
# 4451                  9217     9171
#
# [989 rows x 2 columns]

# %%
indi_user = doll_merged[ doll_merged['agency_name'] == '개인 사용자']
indi_user['tmp']=indi_user[['user_group_member_id', 'user_id']].astype('str').agg('-'.join, axis=1)
unique_groupid_id=indi_user.tmp.value_counts()[indi_user.tmp.value_counts()==1].keys()

indi_user_unique = indi_user[ indi_user['user_group_member_id'].apply(lambda x: x in [int(x[:4]) for x in unique_groupid_id]) ]
indi_userid_cnt = indi_user_unique['user_id'].value_counts()
indi_userid_one = list(indi_userid_cnt[indi_userid_cnt == 1].index)
indi_user_unique_gpuser = indi_user_unique[ indi_user_unique['user_id'].apply(lambda x: x in indi_userid_one) ]

# %%
user_id_cnt = doll_merged['user_id'].value_counts()
one_user = list(user_id_cnt[ user_id_cnt == 1 ].index)

# %%
no_agency = doll_merged[ doll_merged['user_id'].apply(lambda x: x in one_user) ].groupby('is_agency').get_group(0)

# %%
no_agency[no_agency['mac_id'] == '861760040555697']
# Out:
#       doll_id  user_id  battery  active_monitor  sex  HOUR(wakeup)  \
# 1823   130740     8165       82              24    1             7
# 1824   130741     8166      100              24    1             7
# 2514   131824     8456      100              24    1             7
# 2520   131828     8459      100              24    2             7
# 2566   131859     8479      100              24    1             6
#
#       HOUR(breakfast)  HOUR(lunch)  HOUR(dinner)  HOUR(sleep)  ...  relig4  \
# 1823                8           12            18           22  ...     NaN
# 1824                9           11            18           21  ...     NaN
# 2514                8           12            18           22  ...     NaN
# 2520                8           12            18           22  ...     NaN
# 2566                7           12            18           22  ...     NaN
#
#       relig5  religion_alarm  calender_type  is_active_detect  grandFM  \
# 1823     NaN               0              0                 0        1
# 1824     NaN               0              0                 0        1
# 2514     NaN               0              0                 0        1
# 2520     NaN               0              0                 0        1
# 2566     NaN               0              0                 0        1
#
#       honorFM  right_ear_function  left_ear_function  serial_number_y
# 1823        0             0010000            0000100             3670
# 1824        0             0010010            0001101             3670
# 2514        0             1111000            0000111             4212
# 2520        0             0011000            0100110             4214
# 2566        0             0100001            1010000             4229
#
# [5 rows x 53 columns]

# %%
doll_merged[ doll_merged['user_id'].apply(lambda x: x in one_user) ].nunique()
# Out:
# doll_id                 388
# user_id                 388
# battery                  68
# active_monitor           23
# sex                       2
# HOUR(wakeup)             14
# HOUR(breakfast)          15
# HOUR(lunch)              13
# HOUR(dinner)             14
# HOUR(sleep)              16
# ventilation_walk          4
# is_edited                 2
# drug1                     2
# drug2                     2
# drug3                     2
# drug4                     2
# drug5                     2
# drug6                     2
# drug7                     2
# regsted_year              4
# regsted_month            12
# mac_id                  337
# disease1                  2
# disease2                  2
# disease3                  2
# serial_number_x         341
# age                      51
# is_resign                 2
# alarm_emergency           2
# alarm_emergency_call      2
# alarm_low_battery         2
# alarm_disconnect          1
# group_id                388
# agency_code              14
# user_group_member_id    383
# is_host                   1
# is_agency                 2
# agency_name              14
# match_agc                 2
# no_alarm                  2
# relig1                   22
# relig2                   19
# relig3                   18
# relig4                   14
# relig5                    8
# religion_alarm            2
# calender_type             2
# is_active_detect          1
# grandFM                   2
# honorFM                   2
# right_ear_function      101
# left_ear_function       104
# serial_number_y         341
# dtype: int64

# %%
doll_merged.to_csv('doll_merged.csv',index=False)

# %%
#gp_user_id_cnt[ gp_user_id_cnt == 1 ]

# %%
#pr = doll_merged.profile_report()
#pr.to_file('./doll_merged.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
